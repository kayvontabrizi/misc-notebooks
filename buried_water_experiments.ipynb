# %% [markdown]
# # Buried Water Site-Identification Experiments
#
# &nbsp;
#
# ## Overview
#
# A key component of assessing the preference for buried waters in a solvated protein-ligand simulation is identifying and unambiguously defining an "occupancy site" (i.e. a cavity or "pocket" in which internal waters may reside). While designation as a "buried-water site" can be qualitative and subject to questions of simulation timescale and protein flexibility, it's frequently the case that these sites are visible to the eye, and can be defined manually. Yet, they remain difficult to capture concretely by computation. The goal of this notebook is to arrive at a robust and automated method for identifying and defining buried-water occupancy sites, relying on trajectory data with thorough sampling of water-occupancy states.
#
# &nbsp;
#
# ### Preparing a Toy Simulation
# I'd like everything to be easily visualizable, so let's work in 2D. Admittedly, this will lower the complexity of possible cavity arrangements, but hopefully will serve as a sufficient sandbox to attempt various approaches to the site-identification problem.
#
# Let's start by generating fake trajectory data. We need a complex and some solvent. We'll first make the complex trajectory, then overlay solvent frames and delete collisions, `dms-solvate` style. There are four steps to generating the complex:
#
#  1. Generate a hexagonal tiling of tightly-packed complex atoms
#  2. Use an SDF to draw a mask for subselecting the tiled atoms
#  3. Distort the atomic positions by integrating through a non-linear flow-field
#  4. Add random noise to these distorted positions
#  5. Randomly rotate (and possibly flip) each frame
#
# These steps allow easy control over the atomic density and cavity topology, while mimicking protein motions through non-linear transformations and random vibrations.
# We can then solvate each frame of our complex trajectories in two steps:
#
#  1. Generate solvent boxes by randomly placing solvent atoms, discarding any that overlap, until the desired density is reached.
#  2. For each complex frame, overlay a solvent box and discard any colliding solvent atoms.
#
# This solvation procedure has the upside of generating a wide variety of occupancy states, a tricky-to-handle feature of real simulations.
#
# &nbsp;
#
# ### Identifying Bulk vs Buried Solvent
#
# As a first step towards defining occupancy sites, we'd like to distinguish buried solvent atoms from those in the bulk. Seeing as buried solvent atoms are isolated from the bulk, proximity-based clustering is an easy way to classify bulk vs buried. Concretely, we can compute a distance matrix for all solvent atoms, construct a per-atom graph with edges connecting pairs within some distance cutoff, and then discard large connected subgraphs (which must be patches of the bulk solvent). This approach isn't fullproof (consider that the inhabitants of bulk-exposed cavities may frequently be misclassified as bulk), but is fast, and empirically sufficient. As a refinement, we can exclude any cluster (i.e. connected subgraph) without close complex contacts.
#
# Note: As an aside, I suspect a better way of classifying between bulk and buried is to essentially run a heat diffusion model where each atom is a cell, and at each timestep a cell's heat is computed as the average of its proximity-based neighbors' heats. By fixing the heat of protein atoms, and treating all cells with a fixed degree (# of neighbors), the steady-state heat profile should effecitvely represent the likelihood of being buried vs bulk. I've yet to test this though, it seems a bit slow. That said, there's surely plent of literature on [diffusion on a graph](https://www.math.fsu.edu/~bertram/lectures/Diffusion.pdf), maybe fast methods exist.
#
# &nbsp;
#
# ### Comparing Buried Waters across the Trajectory
#
# Having distniguished buried solvent from the bulk, we could now attempt to leverage a single frame to identify protein atoms defining a cavity, based again on proximity. However, in practice there is too much variability to reliably define a cavity from any single frame. We'd like to combine information across frames, but without a reliable global coordinate system (which nonlinear complex-atom motions make unavailable), we've no easy way to do so.
#
# Fortunately, [recent literature offers a method of Local Alignment of Water Sites (LAWS)](https://www.biorxiv.org/content/10.1101/2022.05.12.491708v1.full.pdf), which we can leverage to place solvent atoms identified across a trajectory into a single reference frame. In short, the algorithm is to define each solvent atom in terms of a set of distances to protein atoms, and then to best-reproduce the site by finding the position that optimally satisfies that set of distance restraints in a new reference frame. This optimization is quick and robust, and can be improved by weighting each distance restraint by its size, such that longer restraints are less important than shorter ones.
#
# &nbsp;
#
# ### Contact-Based Clustering and Site Definitions
#
# With all our buried waters now sharing a reference frame, we're free to use our choice of geometry-based clustering methods to define our sites. As before, we can cluster by generating proximity-based graphs and isolating connected subgraphs. We set a _lower_ limit on subgraph size to strip out stragglers, and can now rely on the resultant clusters to define our occupancy sites. In particular, each cluster corresponds to a site, which we can define as the protein atoms within a small distance from any of that cluster's atoms.
#
# &nbsp;
#
# ## Concluding Remarks
#
# And that's it! With our sites now defined in a concrete and geometry-free matter, we can moved forward with whatever occupancy analysis or site-specific binding FEP we'd like to use.
#
# &nbsp;
#
# ##### References:
#  - [LAWS: Local Alignment for Water Sites — tracking ordered water in simulations](https://www.biorxiv.org/content/10.1101/2022.05.12.491708v1.full.pdf)

# %% [markdown]
# -------------------------------

# %%
## imports & configuration

# standard imports
import json

# custom imports
import ipywidgets
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches
import scipy.optimize
import scipy.spatial
import tqdm.notebook

# inline plots
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib notebook

# jupyter theme
try:
    import jupyterthemes as jt
    jt.jtplot.style()
except ImportError:
    pass

# %% [markdown]
# -------------------------------

# %%
## class to represent drawable matplotlib canvas
class Canvas:
    def __init__(self):
        pass

    def init_figure(self, figsize=(5, 3)):
        self.fig, self.ax = plt.subplots(figsize=figsize)
        for s in ['top','bottom','left','right']:
            self.ax.spines[s].set_linewidth(2)
        self.ax.set_aspect('equal', 'box')
        self.ax.set_xlim(0, 1)
        self.ax.set_ylim(0, 1)
        self.ax.xaxis.set_ticks([])
        self.ax.yaxis.set_ticks([])
        self.fig.tight_layout()

    def draw_circles(self, positions, radii, style=None):
        # set default circle style
        style = style or dict(edgecolor="C0", linewidth=2, fill=None)

        # if radius is a scalar, convert to array
        if isinstance(radii, (int, float)):
            radii = radii*np.ones(len(positions))

        # loop through particles
        return [
            self.ax.add_patch(matplotlib.patches.Circle(xy=p, radius=r, **style))
            for i, (p, r) in enumerate(zip(positions, radii))
        ]

# %%
## custom slider ipywidget class
class Slider:
    # build widget objects
    def __init__(self, update_method, index_var, **kwargs):
        # play button
        defaults = dict(value=0, min=0, max=99, step=1, interval=1000, disabled=False)
        defaults.update(kwargs)
        self.play = play = ipywidgets.Play(**defaults)

        # make interactive slider
        self.int_slider = ipywidgets.IntSlider(min=play.min, max=play.max, step=play.step, value=play.value)
        self.slider = ipywidgets.interactive(update_method, **{index_var: self.int_slider})

        # link play button to slider value
        ipywidgets.jslink((self.play, 'value'), (self.slider.children[0], 'value'))

        # construct player widget
        self.player = ipywidgets.HBox([self.play, self.slider])

# %%
## trajectory configuration

# trajectory length
n_frames = 100

# set box size (scaling)
box_size = 70 # Å

# %%
## construct fake protein trajectory

# construct grid of hexagonally-spaced points
def construct_hex_grid(m, n):
    tzip2d = lambda xs, ys: np.concatenate(np.stack(np.meshgrid(xs, ys)).T, axis=0)
    return np.concatenate([
        1+tzip2d(2*np.sqrt(3)*(0+1*np.arange(m//2)), 0+2*np.arange(n//2)),
        1+tzip2d(1*np.sqrt(3)*(1+2*np.arange(m//2)), 1+2*np.arange(n//2)),
    ], axis=0)

# construct protein grid
grid_shape = (32, 56) # rows and columns
margin = 0.4 # fraction of grid radius
n_prot_base = np.prod(grid_shape)
l_max = max(grid_shape[0]*np.sqrt(3), grid_shape[1])
grid_radius = 1/(l_max)
scale = 1/(l_max+1)
grid_pos = scale*(np.array([0.5, 0])+construct_hex_grid(*grid_shape))
prot_radius = (1 - margin)*grid_radius

# propagate grid positions through vector field
field_func = lambda x: np.sin(10*(x-0.5))[:, ::-1]
flow_positions = np.zeros((n_frames, len(grid_pos), 2))
flow_positions[0] = grid_pos
for i in range(1, n_frames):
    flow_positions[i] = flow_positions[i-1]+0.001*field_func(flow_positions[i-1])
    flow_positions[i] = (0.999*(flow_positions[i]-0.5))+0.5

# construct random perturbations
perts = np.random.randn(n_frames, len(grid_pos), 2)
perts /= np.linalg.norm(perts, axis=-1)[:, :, None]
perts *= margin*grid_radius*np.random.random((n_frames, len(grid_pos)))[:, :, None]

# use SDF to subselect from grid
def smin(a, b, k=32):
    res = np.exp2(-k * a) + np.exp2(-k * b)
    return np.log2(res) / -k
sub = lambda x, y, **kwargs: -smin(-x, y, **kwargs)
SDF = lambda x: sub(
    sub(
        sub(
            sub(
                np.linalg.norm(x - np.array([0.5, 0.5]), axis=-1)-0.4,
                np.linalg.norm(x - np.array([0.3, 0.3]), axis=-1)-0.04,
            ),
            np.linalg.norm(x - np.array([0.28, 0.52]), axis=-1)-0.1,
        ),
        smin(
            smin(
                np.linalg.norm(x - np.array([0.5, 0.8]), axis=-1)-0.01,
                np.linalg.norm(x - np.array([0.6, 0.7]), axis=-1)-0.005,
                k=16
            ),
            smin(
                np.linalg.norm(x - np.array([0.7, 0.6]), axis=-1)-0.005,
                np.linalg.norm(x - np.array([0.8, 0.5]), axis=-1)-0.01,
                k=16
            ),
            k=16
        )
    ),
    smin(
        np.linalg.norm(x - np.array([0.6, 0.3]), axis=-1)-0.01,
        np.linalg.norm(x - np.array([0.6, 0.2]), axis=-1)-0.01,
        k=16
    )
)
prot_sel = SDF(grid_pos) < 0.

# output final protein positions
prot_pos = (flow_positions+perts)[:, prot_sel]

# randomly orient each frame
R = lambda th: np.array([[np.cos(th), -np.sin(th)], [np.sin(th), np.cos(th)]])
random_rots = R(2*np.pi*np.random.random(n_frames)).T
random_flips = (2*(np.random.random(n_frames) < 0.5)-1)
random_orients = np.stack([random_flips, np.ones(n_frames)]).T[:, :, None]*random_rots
prot_pos -= 0.5
prot_pos = np.stack([r.dot(p.T).T for r, p in zip(random_orients, prot_pos)])
prot_pos += 0.5

# adjust from 50 Å box
prot_radius *= 50/box_size
prot_pos -= 0.5
prot_pos *= 50/box_size
prot_pos += 0.5

# %%
## construct water trajectories

# compute water-box size at standard state concentration
# (55.345 mol/L * 6.022e23 w/mol 1e3 L/m3 1e-30 m3/Å3) == 0.033328759 w/Å3
s_wat = (1/(55.345 * 6.022e23 * 1e3 * 1e-30))**(1/3) # or 3.10737465 Å / water

# choose a size for water (water radius is 1.925 pm)
r_wat = 1.925*0.5 # Å

# set the number of particles and radii
n_waters = int((box_size**2)/(s_wat**2))

# maximum # of packing attempts per water
n_attempts = 10000

# initialize container
wat_pos = np.nan*np.ones((n_frames, n_waters, 2))

# iterate through frames
for i in tqdm.notebook.tqdm(range(n_frames)):
    # loop through waters
    for j in range(n_waters):
        # try n_attempt times to pack
        for k in range(n_attempts):
            # random position without bounds
            pos = r_wat+(box_size-2*r_wat)*np.random.random(2)

            # compute displacements
            disp = wat_pos[i][:j] - pos[None]

            # if no collisions, add position and break
            if np.all((disp*disp).sum(axis=-1) > (2*r_wat)**2):
                wat_pos[i][j] = pos
                break

        # error if too many attempts without packing!
        if k+1 >= n_attempts:
            raise RuntimeError(f"frame {i} water {j} couldn't be packed with {n_attempts} attempts")

# scale waters
wat_pos /= box_size
wat_radius = r_wat/box_size

# resolve water-protein collisions
_wat_pos = np.copy(wat_pos) # store pre-collision solvent boxes
wat_prot_distances = np.linalg.norm(prot_pos[:, None] - wat_pos[:, :, None], axis=-1)
collisions = np.any(wat_prot_distances < prot_radius+wat_radius, axis=-1)
wat_pos[collisions] = np.array([-1, -1])

# %% [markdown]
# ------------------------

# %%
# construct graphs, drop colliding waters
wat_wat_distances = np.linalg.norm(wat_pos[:, None] - wat_pos[:, :, None], axis=-1)
wat_indices = np.triu_indices(n_waters, k=1)
wat_Gs = [
    nx.Graph(list(np.stack(wat_indices).T[sel]))
    for sel in (wat_wat_distances[(slice(None),) + wat_indices] < 4*wat_radius)
]
_ = [G.add_nodes_from(set(range(n_waters))-set(G.nodes)) for G in wat_Gs]
_ = [wat_Gs[i].remove_nodes_from(np.where(sel)[0]) for i, sel in enumerate(collisions)]

# %%
# identify non-bulk clusters and their contacts
bulk_cutoff = 20
clusters_contacts = [
    {
        j: (nodes, np.where(np.any(wat_prot_distances[i, sorted(nodes)] < 2.5*(wat_radius+prot_radius), axis=0))[0])
        for j, nodes in enumerate(nx.connected_components(G))
        if len(nodes) <= bulk_cutoff
    }
    for i, G in enumerate(wat_Gs)
]
clusters_contacts = [
    {
        k: (ids, contacts)
        for k, (ids, contacts) in data.items()
        if len(contacts) > 0
    }
    for data in clusters_contacts
]
nonbulks = [set.union(*[c[0] for c in cs.values()]) for cs in clusters_contacts]

# %%
## draw interactive canvas

# initialize canvas
canvas = Canvas()
canvas.init_figure(figsize=(7, 7))
circles = []
circles += canvas.draw_circles(wat_pos[0], wat_radius)
circles += canvas.draw_circles(prot_pos[0], prot_radius, style=dict(edgecolor="k", facecolor="#C0C", linewidth=2))
positions = np.concatenate([wat_pos, prot_pos], axis=1)
canvas.lines = []

# method to update canvas each frame
def update(frame):
    # clear old lines and draw new ones
    [l.remove() for l in canvas.lines]
    canvas.lines = [
        canvas.ax.add_line(matplotlib.lines.Line2D(*wat_pos[frame][edge, :].T, c='k'))
        for edge in wat_Gs[frame].edges
    ]

    # iterate through and update circles
    for i, circle in enumerate(circles):
        # highlight nonbulk waters
        if i not in nonbulks[frame]:
            circle.set_alpha(0.2)
        else:
            circle.set_alpha(1.0)

        # reposition circles
        circle.center = positions[frame][i]

    # highlight protein contacts
    for clusters, contacts in clusters_contacts[frame].values():
        for j in contacts:
            circles[n_waters+j].set_alpha(1.0)

# create interactive widget
Slider(update, "frame", max=len(positions)-1).player

# %% [markdown]
# ------------------------------------

# %%
# reconstruct water sites relative to reference protein structure
ref_prot_pos = prot_pos[len(prot_pos)//2]

# %%
# displacement-based approach
sites = []
for i, data in enumerate(clusters_contacts):
    for k, (atoms, contacts) in data.items():
        disps = wat_pos[i][sorted(atoms)][:, None]-prot_pos[i][contacts][None, :]
        assert disps.shape == (len(atoms), len(contacts), 2)
        for disp in disps:
            site_wts = np.zeros((len(prot_pos[0]), 1))
            site_dsp = np.zeros((len(prot_pos[0]), 2))
            inv_dist = 1/np.linalg.norm(disp, axis=-1)
            site_wts[contacts, :] = inv_dist[:, None]/inv_dist.sum()
            site_dsp[contacts, :] = disp
            sites.append((site_wts, site_dsp))

wts, dsps = map(np.array, zip(*sites))
xtal_pos = (wts*(ref_prot_pos[None]+dsps)).sum(axis=1)

# %%
## multilateration-based (LAWS) approach

# compute LAWS "sites"
sites = []
for i, data in enumerate(clusters_contacts):
    for k, (atoms, contacts) in data.items():
        disps = wat_pos[i][sorted(atoms)][:, None]-prot_pos[i][contacts][None, :]
        assert disps.shape == (len(atoms), len(contacts), 2)
        for disp in disps:
            d2s = (disp*disp).sum(axis=-1)
            wts = (1/d2s)/(1/d2s).sum()
            sites.append((np.sqrt(wts), np.sqrt(d2s), contacts))

# for i, (w, d, p) in enumerate(sites):
#     if len(p) < 2: continue
#     opt = scipy.optimize.least_squares(lambda x: w*(np.linalg.norm(x-p, axis=-1)-d), xtal_pos[i], method="lm")
#     assert opt.success

solns = [
#     scipy.optimize.least_squares(lambda x: w*(np.linalg.norm(x-ref_prot_pos[p], axis=-1)-d), xtal_pos[i], method="lm").x
    scipy.optimize.least_squares(lambda x: w*(np.linalg.norm(x-ref_prot_pos[p], axis=-1)-d), np.array([0.5, 0.5]), method="lm")
    for i, (w, d, p) in enumerate(sites)
    if len(p) >= 4
]
top_solns = sorted([(o.cost, i) for i, o in enumerate(solns)])[:-len(solns)//10]
laws_pos = np.array([solns[i].x for c, i in top_solns])

# %%time
# # optimizing all 100 frames simultaneously takes 300 ms, too slow for 1600 copies
# w, d, p = sites[0]
# scipy.optimize.least_squares(
#     lambda x: (w*(np.linalg.norm(x.reshape(-1, 2)[:, None]-prot_pos[:, p], axis=-1)-d)).reshape(-1),
#     np.tile(xtal_pos[0], len(prot_pos)), method="lm"
# ).x.reshape(-1, 2).shape

# %%
# simple distance-based clustering
def distance_graph_clustering(positions, cutoff_distance):
    distances = np.linalg.norm(positions[None] - positions[:, None], axis=-1)
    indices = np.triu_indices(len(positions), k=1)
    sel = distances[indices] < cutoff_distance
    return nx.Graph(list(np.stack(indices).T[sel]))

# %%
# isolate LAWS clusters and contacts
G = distance_graph_clustering(laws_pos, 0.02)
laws_clusters = [x for x in nx.connected_components(G) if len(x) > 10]
laws_contacts = [
    np.where(np.any(
        scipy.spatial.distance_matrix(laws_pos[sorted(nodes)], ref_prot_pos) < 1.5*(wat_radius+prot_radius), axis=0
    ))[0]
    for nodes in laws_clusters
]

# %%
# visualize results
_canvas = Canvas()
_canvas.init_figure(figsize=(7, 7))
_canvas.circles = []
_canvas.circles += _canvas.draw_circles(ref_prot_pos, prot_radius, style=dict(edgecolor="k", facecolor="#C0C", linewidth=2))
cmap = {-1: 'k', 0: 'r', 1: 'g', 2: 'b', 3: '#FF0', 4: '#0FF', 5: '#F0F'}
for i, cluster in enumerate(laws_clusters):
    _canvas.circles += _canvas.draw_circles(
        laws_pos[sorted(cluster)], wat_radius/4, style=dict(facecolor=cmap[i], linewidth=0)
    )
    n_cluster = len(cluster)
for i, cluster in enumerate(laws_clusters):
    _canvas.draw_circles(ref_prot_pos[laws_contacts[i]], prot_radius, style=dict(edgecolor="k", facecolor=cmap[i], linewidth=2))

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# Breaking down the setup into visualizations to facilitate explanation:

# %%
## visualize protein selection SDF

# evalaute SDF over grid
X, Y = np.meshgrid(np.linspace(0, 1, 50), np.linspace(0, 1, 50))
Z = SDF(np.concatenate(np.stack([Y, X]).T)).reshape(X.shape)

# view SDF
plt.figure()
plt.title("SDF")
plt.contourf(X, Y, Z, levels=10)
plt.colorbar()
plt.tight_layout()

# %%
## visualize distortion vector field

# compute vector field
pts = np.concatenate(np.stack(np.meshgrid(np.linspace(0, 1, 30), np.linspace(0, 1, 30)), axis=0).T)

# view vector field
plt.figure()
plt.title("$f(x, y) = (sin(y), sin(x))$")
plt.quiver(*pts.T, *field_func(pts).T)
plt.tight_layout()

# %%
## view raw trajectory

# initialize canvas
_canvas = Canvas()
_canvas.init_figure(figsize=(7, 7))
_circles = []
# _circles += _canvas.draw_circles(wat_pos[0], wat_radius)
# _circles += _canvas.draw_circles(prot_pos[0], prot_radius, style=dict(edgecolor="k", facecolor="#C0C", linewidth=2))
# _positions = np.concatenate([wat_pos, prot_pos], axis=1)
_positions = np.copy(prot_pos)
_positions -= 0.5
_positions = np.stack([np.linalg.inv(r).dot(p.T).T for r, p in zip(random_orients, _positions)])
_positions += 0.5
_circles += _canvas.draw_circles(_positions[0], prot_radius, style=dict(edgecolor="k", facecolor="#C0C", linewidth=2))

# method to update canvas each frame
def old_update(frame):
    # iterate through and update circles
    for i, circle in enumerate(_circles):
        # reposition _circles
        circle.center = _positions[frame][i]

# create interactive widget
Slider(old_update, "frame", max=len(_positions)-1, interval=200).player

# %%
## view raw trajectory

# initialize canvas
_canvas = Canvas()
_canvas.init_figure(figsize=(7, 7))
_circles = []
_circles += _canvas.draw_circles(wat_pos[0], wat_radius)
_positions = _wat_pos

# method to update canvas each frame
def old_update(frame):
    # iterate through and update circles
    for i, circle in enumerate(_circles):
        # reposition _circles
        circle.center = _positions[frame][i]

# create interactive widget
Slider(old_update, "frame", max=len(_positions)-1, interval=200).player

# %% [markdown]
# -------------------------
